# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# c:\Users\Sashen\anaconda3\envs\c721_ml\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Clean Up

# %% [markdown]
# ## Per Capita Return

# %%
df_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5", "SC6"], dtype=float)
df_per_capita_return
# Out:
#           SC0  SC1  SC2  SC3  SC4  SC5  SC6
# A3C       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# A3C NPS   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# PPO       NaN  NaN  NaN  NaN  NaN  NaN  NaN
# PPO NPS   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# R2D2      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# R2D2 NPS  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Filling in values for first column of dataframe
df_per_capita_return["SC0"]["A3C"] = 19.6
df_per_capita_return["SC0"]["A3C NPS"] = 16.3
df_per_capita_return["SC0"]["PPO"] = 49.0
df_per_capita_return["SC0"]["PPO NPS"] = 38.4
df_per_capita_return["SC0"]["R2D2"] = 21.9
df_per_capita_return["SC0"]["R2D2 NPS"] = 1.1

# Filling in values for second column of dataframe
df_per_capita_return["SC1"]["A3C"] = 0.0
df_per_capita_return["SC1"]["A3C NPS"] = 0.0
df_per_capita_return["SC1"]["PPO"] = 0.0
df_per_capita_return["SC1"]["PPO NPS"] = 0.0
df_per_capita_return["SC1"]["R2D2"] = 0.0
df_per_capita_return["SC1"]["R2D2 NPS"] = 0.0

# Filling in values for third column of dataframe
df_per_capita_return["SC2"]["A3C"] = 78.1
df_per_capita_return["SC2"]["A3C NPS"] = 89.0
df_per_capita_return["SC2"]["PPO"] = 104.9
df_per_capita_return["SC2"]["PPO NPS"] = 77.6
df_per_capita_return["SC2"]["R2D2"] = 93.6
df_per_capita_return["SC2"]["R2D2 NPS"] = 71.0

# Filling in values for fourth column of dataframe
df_per_capita_return["SC3"]["A3C"] = 42.7
df_per_capita_return["SC3"]["A3C NPS"] = 51.7
df_per_capita_return["SC3"]["PPO"] = 50.0
df_per_capita_return["SC3"]["PPO NPS"] = 72.1
df_per_capita_return["SC3"]["R2D2"] = 49.7
df_per_capita_return["SC3"]["R2D2 NPS"] = 42.4

# Filling in values for fifth column of dataframe
df_per_capita_return["SC4"]["A3C"] = 31.6
df_per_capita_return["SC4"]["A3C NPS"] = 28.3
df_per_capita_return["SC4"]["PPO"] = 21.1
df_per_capita_return["SC4"]["PPO NPS"] = 44.6
df_per_capita_return["SC4"]["R2D2"] = 13.4
df_per_capita_return["SC4"]["R2D2 NPS"] = 0.0

# Filling in values for sixth column of dataframe
df_per_capita_return["SC5"]["A3C"] = 39.9
df_per_capita_return["SC5"]["A3C NPS"] = 47.6
df_per_capita_return["SC5"]["PPO"] = 12.0
df_per_capita_return["SC5"]["PPO NPS"] = 26.3
df_per_capita_return["SC5"]["R2D2"] = 39.9
df_per_capita_return["SC5"]["R2D2 NPS"] = 0.0

# Filling in values for seventh column of dataframe
df_per_capita_return["SC6"]["A3C"] = 13.0
df_per_capita_return["SC6"]["A3C NPS"] = 22.9
df_per_capita_return["SC6"]["PPO"] = 23.9
df_per_capita_return["SC6"]["PPO NPS"] = 31.3
df_per_capita_return["SC6"]["R2D2"] = 0.0
df_per_capita_return["SC6"]["R2D2 NPS"] = 0.0

df_per_capita_return
# Out:
#            SC0  SC1    SC2   SC3   SC4   SC5   SC6
# A3C       19.6  0.0   78.1  42.7  31.6  39.9  13.0
# A3C NPS   16.3  0.0   89.0  51.7  28.3  47.6  22.9
# PPO       49.0  0.0  104.9  50.0  21.1  12.0  23.9
# PPO NPS   38.4  0.0   77.6  72.1  44.6  26.3  31.3
# R2D2      21.9  0.0   93.6  49.7  13.4  39.9   0.0
# R2D2 NPS   1.1  0.0   71.0  42.4   0.0   0.0   0.0

# %%
# min-max normalization of dataframe
df_per_capita_return = (df_per_capita_return - df_per_capita_return.min()) / (df_per_capita_return.max() - df_per_capita_return.min())
df_per_capita_return.fillna(0.0, inplace=True)
df_per_capita_return
# Out:
#                SC0  SC1       SC2       SC3       SC4       SC5       SC6
# A3C       0.386221  0.0  0.209440  0.010101  0.708520  0.838235  0.415335
# A3C NPS   0.317328  0.0  0.530973  0.313131  0.634529  1.000000  0.731629
# PPO       1.000000  0.0  1.000000  0.255892  0.473094  0.252101  0.763578
# PPO NPS   0.778706  0.0  0.194690  1.000000  1.000000  0.552521  1.000000
# R2D2      0.434238  0.0  0.666667  0.245791  0.300448  0.838235  0.000000
# R2D2 NPS  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_per_capita_return, annot=True, cmap="coolwarm") # YlGnBu, "rocket", "rocket_r"
plt.title("Cleanup - Per Capita Return")
plt.show()

# %% [markdown]
# ## Focal Per Capita Return

# %%
df_focal_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5", "SC6"], dtype=np.float64)

# %%
# Filling in values for first column of dataframe
df_focal_per_capita_return["SC0"]["A3C"] = 45.7
df_focal_per_capita_return["SC0"]["A3C NPS"] = 37.0
df_focal_per_capita_return["SC0"]["PPO"] = 114.3
df_focal_per_capita_return["SC0"]["PPO NPS"] = 90.0
df_focal_per_capita_return["SC0"]["R2D2"] = 51.0
df_focal_per_capita_return["SC0"]["R2D2 NPS"] = 2.7

# Filling in values for second column of dataframe
df_focal_per_capita_return["SC1"]["A3C"] = 0.0
df_focal_per_capita_return["SC1"]["A3C NPS"] = 0.0
df_focal_per_capita_return["SC1"]["PPO"] = 0.0
df_focal_per_capita_return["SC1"]["PPO NPS"] = 0.0
df_focal_per_capita_return["SC1"]["R2D2"] = 0.0
df_focal_per_capita_return["SC1"]["R2D2 NPS"] = 0.0

# Filling in values for third column of dataframe
df_focal_per_capita_return["SC2"]["A3C"] = 45.0
df_focal_per_capita_return["SC2"]["A3C NPS"] = 52.0
df_focal_per_capita_return["SC2"]["PPO"] = 73.3
df_focal_per_capita_return["SC2"]["PPO NPS"] = 30.3
df_focal_per_capita_return["SC2"]["R2D2"] = 52.3
df_focal_per_capita_return["SC2"]["R2D2 NPS"] = 5.3

# Filling in values for fourth column of dataframe
df_focal_per_capita_return["SC3"]["A3C"] = 29.0
df_focal_per_capita_return["SC3"]["A3C NPS"] = 30.3
df_focal_per_capita_return["SC3"]["PPO"] = 15.0
df_focal_per_capita_return["SC3"]["PPO NPS"] = 47.3
df_focal_per_capita_return["SC3"]["R2D2"] = 35.7
df_focal_per_capita_return["SC3"]["R2D2 NPS"] = 13.7

# Filling in values for fifth column of dataframe
df_focal_per_capita_return["SC4"]["A3C"] = 36.8
df_focal_per_capita_return["SC4"]["A3C NPS"] = 33.0
df_focal_per_capita_return["SC4"]["PPO"] = 24.7
df_focal_per_capita_return["SC4"]["PPO NPS"] = 52.3
df_focal_per_capita_return["SC4"]["R2D2"] = 11.3
df_focal_per_capita_return["SC4"]["R2D2 NPS"] = 0.0

# Filling in values for sixth column of dataframe
df_focal_per_capita_return["SC5"]["A3C"] = 55.8
df_focal_per_capita_return["SC5"]["A3C NPS"] = 66.6
df_focal_per_capita_return["SC5"]["PPO"] = 16.8
df_focal_per_capita_return["SC5"]["PPO NPS"] = 36.8
df_focal_per_capita_return["SC5"]["R2D2"] = 34.4
df_focal_per_capita_return["SC5"]["R2D2 NPS"] = 0.0

# Filling in values for seventh column of dataframe
df_focal_per_capita_return["SC6"]["A3C"] = 15.2
df_focal_per_capita_return["SC6"]["A3C NPS"] = 22.9
df_focal_per_capita_return["SC6"]["PPO"] = 23.9
df_focal_per_capita_return["SC6"]["PPO NPS"] = 31.3
df_focal_per_capita_return["SC6"]["R2D2"] = 0.0
df_focal_per_capita_return["SC6"]["R2D2 NPS"] = 0.0

# %%
# min-max normalization of dataframe
df_focal_per_capita_return = (df_focal_per_capita_return - df_focal_per_capita_return.min()) / (df_focal_per_capita_return.max() - df_focal_per_capita_return.min())
df_focal_per_capita_return.fillna(0.0, inplace=True)
df_focal_per_capita_return
# Out:
#                SC0  SC1       SC2       SC3       SC4       SC5       SC6
# A3C       0.385305  0.0  0.583824  0.455357  0.703633  0.837838  0.485623
# A3C NPS   0.307348  0.0  0.686765  0.494048  0.630975  1.000000  0.731629
# PPO       1.000000  0.0  1.000000  0.038690  0.472275  0.252252  0.763578
# PPO NPS   0.782258  0.0  0.367647  1.000000  1.000000  0.552553  1.000000
# R2D2      0.432796  0.0  0.691176  0.654762  0.216061  0.516517  0.000000
# R2D2 NPS  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_focal_per_capita_return, annot=True, cmap="coolwarm")
plt.title("Clean Up - Focal Per Capita Return")
plt.show()

# %% [markdown]
# ## Background Per Capita Return

# %%
background_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5", "SC6"], dtype=np.float64)

# %%
# Filling in values for first column of dataframe
background_per_capita_return["SC0"]["A3C"] = 0.0
background_per_capita_return["SC0"]["A3C NPS"] = 0.8
background_per_capita_return["SC0"]["PPO"] = 0.0
background_per_capita_return["SC0"]["PPO NPS"] = 0.0
background_per_capita_return["SC0"]["R2D2"] = 0.0
background_per_capita_return["SC0"]["R2D2 NPS"] = 0.0

# Filling in values for second column of dataframe
background_per_capita_return["SC1"]["A3C"] = 0.0
background_per_capita_return["SC1"]["A3C NPS"] = 0.0
background_per_capita_return["SC1"]["PPO"] = 0.0
background_per_capita_return["SC1"]["PPO NPS"] = 0.0
background_per_capita_return["SC1"]["R2D2"] = 0.0
background_per_capita_return["SC1"]["R2D2 NPS"] = 0.0

# Filling in values for third column of dataframe
background_per_capita_return["SC2"]["A3C"] = 103.0
background_per_capita_return["SC2"]["A3C NPS"] = 116.8
background_per_capita_return["SC2"]["PPO"] = 128.5
background_per_capita_return["SC2"]["PPO NPS"] = 113.0
background_per_capita_return["SC2"]["R2D2"] = 124.5
background_per_capita_return["SC2"]["R2D2 NPS"] = 120.3

# Filling in values for fourth column of dataframe
background_per_capita_return["SC3"]["A3C"] = 53.0
background_per_capita_return["SC3"]["A3C NPS"] = 67.8
background_per_capita_return["SC3"]["PPO"] = 76.3
background_per_capita_return["SC3"]["PPO NPS"] = 90.8
background_per_capita_return["SC3"]["R2D2"] = 60.3
background_per_capita_return["SC3"]["R2D2 NPS"] = 64.0

# Filling in values for fifth column of dataframe
background_per_capita_return["SC4"]["A3C"] = 0.0
background_per_capita_return["SC4"]["A3C NPS"] = 0.0
background_per_capita_return["SC4"]["PPO"] = 0.0
background_per_capita_return["SC4"]["PPO NPS"] = 0.0
background_per_capita_return["SC4"]["R2D2"] = 26.0
background_per_capita_return["SC4"]["R2D2 NPS"] = 0.0

# Filling in values for sixth column of dataframe
background_per_capita_return["SC5"]["A3C"] = 0.0
background_per_capita_return["SC5"]["A3C NPS"] = 0.0
background_per_capita_return["SC5"]["PPO"] = 0.0
background_per_capita_return["SC5"]["PPO NPS"] = 0.0
background_per_capita_return["SC5"]["R2D2"] = 53.5
background_per_capita_return["SC5"]["R2D2 NPS"] = 0.0

# Filling in values for seventh column of dataframe
background_per_capita_return["SC6"]["A3C"] = 0.0
background_per_capita_return["SC6"]["A3C NPS"] = 39.0
background_per_capita_return["SC6"]["PPO"] = 0.0
background_per_capita_return["SC6"]["PPO NPS"] = 102.0
background_per_capita_return["SC6"]["R2D2"] = 0.0
background_per_capita_return["SC6"]["R2D2 NPS"] = 0.0

# %%
# min-max normalization of dataframe
background_per_capita_return = (background_per_capita_return - background_per_capita_return.min()) / (background_per_capita_return.max() - background_per_capita_return.min())
background_per_capita_return.fillna(0.0, inplace=True)
background_per_capita_return
# Out:
#           SC0  SC1       SC2       SC3  SC4  SC5       SC6
# A3C       0.0  0.0  0.000000  0.000000  0.0  0.0  0.000000
# A3C NPS   1.0  0.0  0.541176  0.391534  0.0  0.0  0.382353
# PPO       0.0  0.0  1.000000  0.616402  0.0  0.0  0.000000
# PPO NPS   0.0  0.0  0.392157  1.000000  0.0  0.0  1.000000
# R2D2      0.0  0.0  0.843137  0.193122  1.0  1.0  0.000000
# R2D2 NPS  0.0  0.0  0.678431  0.291005  0.0  0.0  0.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(background_per_capita_return, annot=True, cmap="coolwarm")
plt.title("Clean Up - Background Per Capita Return")
plt.show()

# %% [markdown]
# ## Utilitarian

# %%
df_utilitarian = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5", "SC6"], dtype=np.float64)

# %%
# Fill in values for first column of dataframe
df_utilitarian["SC0"]["A3C"] = 0.1
df_utilitarian["SC0"]["A3C NPS"] = 0.1
df_utilitarian["SC0"]["PPO"] = 0.3
df_utilitarian["SC0"]["PPO NPS"] = 0.3
df_utilitarian["SC0"]["R2D2"] = 0.2
df_utilitarian["SC0"]["R2D2 NPS"] = 0.0

# Fill in values for second column of dataframe
df_utilitarian["SC1"]["A3C"] = 0.0
df_utilitarian["SC1"]["A3C NPS"] = 0.0
df_utilitarian["SC1"]["PPO"] = 0.0
df_utilitarian["SC1"]["PPO NPS"] = 0.0
df_utilitarian["SC1"]["R2D2"] = 0.0
df_utilitarian["SC1"]["R2D2 NPS"] = 0.0

# Fill in values for third column of dataframe
df_utilitarian["SC2"]["A3C"] = 0.5
df_utilitarian["SC2"]["A3C NPS"] = 0.6
df_utilitarian["SC2"]["PPO"] = 0.7
df_utilitarian["SC2"]["PPO NPS"] = 0.5
df_utilitarian["SC2"]["R2D2"] = 0.7
df_utilitarian["SC2"]["R2D2 NPS"] = 0.5

# Fill in values for fourth column of dataframe
df_utilitarian["SC3"]["A3C"] = 0.3
df_utilitarian["SC3"]["A3C NPS"] = 0.4
df_utilitarian["SC3"]["PPO"] = 0.4
df_utilitarian["SC3"]["PPO NPS"] = 0.5
df_utilitarian["SC3"]["R2D2"] = 0.3
df_utilitarian["SC3"]["R2D2 NPS"] = 0.3

# Fill in values for fifth column of dataframe
df_utilitarian["SC4"]["A3C"] = 0.2
df_utilitarian["SC4"]["A3C NPS"] = 0.2
df_utilitarian["SC4"]["PPO"] = 0.1
df_utilitarian["SC4"]["PPO NPS"] = 0.3
df_utilitarian["SC4"]["R2D2"] = 0.1
df_utilitarian["SC4"]["R2D2 NPS"] = 0.0

# Fill in values for sixth column of dataframe
df_utilitarian["SC5"]["A3C"] = 0.279
df_utilitarian["SC5"]["A3C NPS"] = 0.333
df_utilitarian["SC5"]["PPO"] = 0.084
df_utilitarian["SC5"]["PPO NPS"] = 0.184
df_utilitarian["SC5"]["R2D2"] = 0.279
df_utilitarian["SC5"]["R2D2 NPS"] = 0.0

# Fill in values for seventh column of dataframe
df_utilitarian["SC6"]["A3C"] = 0.091
df_utilitarian["SC6"]["A3C NPS"] = 0.16
df_utilitarian["SC6"]["PPO"] = 0.167
df_utilitarian["SC6"]["PPO NPS"] = 0.219
df_utilitarian["SC6"]["R2D2"] = 0.0
df_utilitarian["SC6"]["R2D2 NPS"] = 0.0

# %%
# min-max normalization of dataframe
df_utilitarian = (df_utilitarian - df_utilitarian.min()) / (df_utilitarian.max() - df_utilitarian.min())
df_utilitarian.fillna(0.0, inplace=True)
df_utilitarian
# Out:
#                SC0  SC1  SC2  SC3       SC4       SC5       SC6
# A3C       0.333333  0.0  0.0  0.0  0.666667  0.837838  0.415525
# A3C NPS   0.333333  0.0  0.5  0.5  0.666667  1.000000  0.730594
# PPO       1.000000  0.0  1.0  0.5  0.333333  0.252252  0.762557
# PPO NPS   1.000000  0.0  0.0  1.0  1.000000  0.552553  1.000000
# R2D2      0.666667  0.0  1.0  0.0  0.333333  0.837838  0.000000
# R2D2 NPS  0.000000  0.0  0.0  0.0  0.000000  0.000000  0.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_utilitarian, annot=True, cmap="coolwarm")
plt.title("Clean Up - Utilitarian")
plt.show()

# %%
# Plottng all the heatmaps together in a 2x2 grid
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
sns.heatmap(df_focal_per_capita_return, annot=True, cmap="coolwarm", ax=axs[0, 0])
axs[0, 0].set_title("Focal Per Capita Return")
sns.heatmap(background_per_capita_return, annot=True, cmap="coolwarm", ax=axs[0, 1])
axs[0, 1].set_title("Background Per Capita Return")
sns.heatmap(df_per_capita_return, annot=True, cmap="coolwarm", ax=axs[1, 0])
axs[1, 0].set_title("Per Capita Return")
sns.heatmap(df_utilitarian, annot=True, cmap="coolwarm", ax=axs[1, 1])
axs[1, 1].set_title("Utilitarian")
plt.show()

# %% [markdown]
# # Prisoner's Dilemma

# %% [markdown]
# ## Per Capita Return

# %%
df_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5"], dtype=np.float64)

# %%
# Fill in values for first column of dataframe
df_per_capita_return["SC0"]["A3C"] = 9.9
df_per_capita_return["SC0"]["A3C NPS"] = 10.2
df_per_capita_return["SC0"]["PPO"] = 12.7
df_per_capita_return["SC0"]["PPO NPS"] = 9.1
df_per_capita_return["SC0"]["R2D2"] = 10.4
df_per_capita_return["SC0"]["R2D2 NPS"] = 11.0

# Fill in values for second column of dataframe
df_per_capita_return["SC1"]["A3C"] = 2.9
df_per_capita_return["SC1"]["A3C NPS"] = 4.5
df_per_capita_return["SC1"]["PPO"] = 3.8
df_per_capita_return["SC1"]["PPO NPS"] = 2.1
df_per_capita_return["SC1"]["R2D2"] = 2.4
df_per_capita_return["SC1"]["R2D2 NPS"] = 2.0

# Fill in values for third column of dataframe
df_per_capita_return["SC2"]["A3C"] = 3.3
df_per_capita_return["SC2"]["A3C NPS"] = 3.4
df_per_capita_return["SC2"]["PPO"] = 3.0
df_per_capita_return["SC2"]["PPO NPS"] = 4.6
df_per_capita_return["SC2"]["R2D2"] = 2.9
df_per_capita_return["SC2"]["R2D2 NPS"] = 2.8

# Fill in values for fourth column of dataframe
df_per_capita_return["SC3"]["A3C"] = 4.2
df_per_capita_return["SC3"]["A3C NPS"] = 4.1
df_per_capita_return["SC3"]["PPO"] = 6.3
df_per_capita_return["SC3"]["PPO NPS"] = 5.0
df_per_capita_return["SC3"]["R2D2"] = 5.2
df_per_capita_return["SC3"]["R2D2 NPS"] = 3.6

# Fill in values for fifth column of dataframe
df_per_capita_return["SC4"]["A3C"] = 9.2
df_per_capita_return["SC4"]["A3C NPS"] = 9.2
df_per_capita_return["SC4"]["PPO"] = 8.3
df_per_capita_return["SC4"]["PPO NPS"] = 10.9
df_per_capita_return["SC4"]["R2D2"] = 9.0
df_per_capita_return["SC4"]["R2D2 NPS"] = 6.5

# Fill in values for sixth column of dataframe
df_per_capita_return["SC5"]["A3C"] = 10.5
df_per_capita_return["SC5"]["A3C NPS"] = 8.6
df_per_capita_return["SC5"]["PPO"] = 11.45
df_per_capita_return["SC5"]["PPO NPS"] = 11.5
df_per_capita_return["SC5"]["R2D2"] = 11.4
df_per_capita_return["SC5"]["R2D2 NPS"] = 11.3

# %%
# min-max normalization of dataframe
df_per_capita_return = (df_per_capita_return - df_per_capita_return.min()) / (df_per_capita_return.max() - df_per_capita_return.min())
df_per_capita_return.fillna(0.0, inplace=True)
df_per_capita_return
# Out:
#                SC0   SC1       SC2       SC3       SC4       SC5
# A3C       0.222222  0.36  0.277778  0.222222  0.613636  0.655172
# A3C NPS   0.305556  1.00  0.333333  0.185185  0.613636  0.000000
# PPO       1.000000  0.72  0.111111  1.000000  0.409091  0.982759
# PPO NPS   0.000000  0.04  1.000000  0.518519  1.000000  1.000000
# R2D2      0.361111  0.16  0.055556  0.592593  0.568182  0.965517
# R2D2 NPS  0.527778  0.00  0.000000  0.000000  0.000000  0.931034

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_per_capita_return, annot=True, cmap="coolwarm")
plt.title("Prisoner's Dilemma - Per Capita Return")
plt.show()

# %% [markdown]
# ## Focal Per Capita Return

# %%
df_focal_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5"], dtype=np.float64)

# %%
# Fill in values for first column of dataframe
df_focal_per_capita_return["SC0"]["A3C"] = 0.3
df_focal_per_capita_return["SC0"]["A3C NPS"] = 0.0
df_focal_per_capita_return["SC0"]["PPO"] = 0.0
df_focal_per_capita_return["SC0"]["PPO NPS"] = 2.8
df_focal_per_capita_return["SC0"]["R2D2"] = 3.8
df_focal_per_capita_return["SC0"]["R2D2 NPS"] = 0.0

# Fill in values for second column of dataframe
df_focal_per_capita_return["SC1"]["A3C"] = 1.3
df_focal_per_capita_return["SC1"]["A3C NPS"] = 3.3
df_focal_per_capita_return["SC1"]["PPO"] = 1.0
df_focal_per_capita_return["SC1"]["PPO NPS"] = 0.8
df_focal_per_capita_return["SC1"]["R2D2"] = 2.1
df_focal_per_capita_return["SC1"]["R2D2 NPS"] = 1.7

# Fill in values for third column of dataframe
df_focal_per_capita_return["SC2"]["A3C"] = 1.0
df_focal_per_capita_return["SC2"]["A3C NPS"] = 2.1
df_focal_per_capita_return["SC2"]["PPO"] = 0.7
df_focal_per_capita_return["SC2"]["PPO NPS"] = 0.7
df_focal_per_capita_return["SC2"]["R2D2"] = 0.9
df_focal_per_capita_return["SC2"]["R2D2 NPS"] = 0.5

# Fill in values for fourth column of dataframe
df_focal_per_capita_return["SC3"]["A3C"] = 0.4
df_focal_per_capita_return["SC3"]["A3C NPS"] = 0.2
df_focal_per_capita_return["SC3"]["PPO"] = 2.1
df_focal_per_capita_return["SC3"]["PPO NPS"] = 0.3
df_focal_per_capita_return["SC3"]["R2D2"] = 1.6
df_focal_per_capita_return["SC3"]["R2D2 NPS"] = 0.3

# Fill in values for fifth column of dataframe
df_focal_per_capita_return["SC4"]["A3C"] = 3.0
df_focal_per_capita_return["SC4"]["A3C NPS"] = 3.8
df_focal_per_capita_return["SC4"]["PPO"] = 0.0
df_focal_per_capita_return["SC4"]["PPO NPS"] = 0.0
df_focal_per_capita_return["SC4"]["R2D2"] = 8.0
df_focal_per_capita_return["SC4"]["R2D2 NPS"] = 0.0

# Fill in values for sixth column of dataframe
df_focal_per_capita_return["SC5"]["A3C"] = 12.0
df_focal_per_capita_return["SC5"]["A3C NPS"] = 0.0
df_focal_per_capita_return["SC5"]["PPO"] = 8.0
df_focal_per_capita_return["SC5"]["PPO NPS"] = 10.8
df_focal_per_capita_return["SC5"]["R2D2"] = 6.2
df_focal_per_capita_return["SC5"]["R2D2 NPS"] = 3.0

# %%
# min-max normalization of dataframe
df_focal_per_capita_return = (df_focal_per_capita_return - df_focal_per_capita_return.min()) / (df_focal_per_capita_return.max() - df_focal_per_capita_return.min())
df_focal_per_capita_return.fillna(0.0, inplace=True)
df_focal_per_capita_return
# Out:
#                SC0   SC1     SC2       SC3    SC4       SC5
# A3C       0.078947  0.20  0.3125  0.105263  0.375  1.000000
# A3C NPS   0.000000  1.00  1.0000  0.000000  0.475  0.000000
# PPO       0.000000  0.08  0.1250  1.000000  0.000  0.666667
# PPO NPS   0.736842  0.00  0.1250  0.052632  0.000  0.900000
# R2D2      1.000000  0.52  0.2500  0.736842  1.000  0.516667
# R2D2 NPS  0.000000  0.36  0.0000  0.052632  0.000  0.250000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_focal_per_capita_return, annot=True, cmap="coolwarm")
plt.title("Prisoner's Dilemma - Focal Per Capita Return")
plt.show()

# %% [markdown]
# ## Background Per Capita Return

# %%
df_background_per_capita_return = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5"], dtype=np.float64)

# %%
# Fill in values for first column of dataframe
df_background_per_capita_return["SC0"]["A3C"] = 11.3
df_background_per_capita_return["SC0"]["A3C NPS"] = 11.7
df_background_per_capita_return["SC0"]["PPO"] = 14.5
df_background_per_capita_return["SC0"]["PPO NPS"] = 10.0
df_background_per_capita_return["SC0"]["R2D2"] = 11.3
df_background_per_capita_return["SC0"]["R2D2 NPS"] = 12.5

# Fill in values for second column of dataframe
df_background_per_capita_return["SC1"]["A3C"] = 7.4
df_background_per_capita_return["SC1"]["A3C NPS"] = 8.0
df_background_per_capita_return["SC1"]["PPO"] = 12.4
df_background_per_capita_return["SC1"]["PPO NPS"] = 5.9
df_background_per_capita_return["SC1"]["R2D2"] = 3.5
df_background_per_capita_return["SC1"]["R2D2 NPS"] = 3.1

# Fill in values for third column of dataframe
df_background_per_capita_return["SC2"]["A3C"] = 10.3
df_background_per_capita_return["SC2"]["A3C NPS"] = 7.4
df_background_per_capita_return["SC2"]["PPO"] = 10.1
df_background_per_capita_return["SC2"]["PPO NPS"] = 16.3
df_background_per_capita_return["SC2"]["R2D2"] = 9.0
df_background_per_capita_return["SC2"]["R2D2 NPS"] = 9.8

# Fill in values for fourth column of dataframe
df_background_per_capita_return["SC3"]["A3C"] = 8.0
df_background_per_capita_return["SC3"]["A3C NPS"] = 7.9
df_background_per_capita_return["SC3"]["PPO"] = 10.5
df_background_per_capita_return["SC3"]["PPO NPS"] = 9.8
df_background_per_capita_return["SC3"]["R2D2"] = 8.7
df_background_per_capita_return["SC3"]["R2D2 NPS"] = 6.8

# Fill in values for fifth column of dataframe
df_background_per_capita_return["SC4"]["A3C"] = 10.0
df_background_per_capita_return["SC4"]["A3C NPS"] = 10.0
df_background_per_capita_return["SC4"]["PPO"] = 9.4
df_background_per_capita_return["SC4"]["PPO NPS"] = 12.5
df_background_per_capita_return["SC4"]["R2D2"] = 9.1
df_background_per_capita_return["SC4"]["R2D2 NPS"] = 7.4

# Fill in values for sixth column of dataframe
df_background_per_capita_return["SC5"]["A3C"] = 10.3
df_background_per_capita_return["SC5"]["A3C NPS"] = 9.8
df_background_per_capita_return["SC5"]["PPO"] = 11.9
df_background_per_capita_return["SC5"]["PPO NPS"] = 11.6
df_background_per_capita_return["SC5"]["R2D2"] = 12.2
df_background_per_capita_return["SC5"]["R2D2 NPS"] = 12.4

# %%
# min-max normalization of dataframe
df_background_per_capita_return = (df_background_per_capita_return - df_background_per_capita_return.min()) / (df_background_per_capita_return.max() - df_background_per_capita_return.min())
df_background_per_capita_return.fillna(0.0, inplace=True)
df_background_per_capita_return
# Out:
#                SC0       SC1       SC2       SC3       SC4       SC5
# A3C       0.288889  0.462366  0.325843  0.324324  0.509804  0.192308
# A3C NPS   0.377778  0.526882  0.000000  0.297297  0.509804  0.000000
# PPO       1.000000  1.000000  0.303371  1.000000  0.392157  0.807692
# PPO NPS   0.000000  0.301075  1.000000  0.810811  1.000000  0.692308
# R2D2      0.288889  0.043011  0.179775  0.513514  0.333333  0.923077
# R2D2 NPS  0.555556  0.000000  0.269663  0.000000  0.000000  1.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_background_per_capita_return, annot=True, cmap="coolwarm")
plt.title("Prisoner's Dilemma - Background Per Capita Return")
plt.show()

# %% [markdown]
# ## Utilitarian

# %%
df_utilitarian = pd.DataFrame(index=["A3C", "A3C NPS", "PPO", "PPO NPS", "R2D2", "R2D2 NPS"], columns=["SC0", "SC1", "SC2", "SC3", "SC4", "SC5"], dtype=np.float64)

# %%
# Fill in values for first column of dataframe
df_utilitarian["SC0"]["A3C"] = 0.07
df_utilitarian["SC0"]["A3C NPS"] = 0.08
df_utilitarian["SC0"]["PPO"] = 0.1
df_utilitarian["SC0"]["PPO NPS"] = 0.07
df_utilitarian["SC0"]["R2D2"] = 0.08
df_utilitarian["SC0"]["R2D2 NPS"] = 0.08

# Fill in values for second column of dataframe
df_utilitarian["SC1"]["A3C"] = 0.02
df_utilitarian["SC1"]["A3C NPS"] = 0.03
df_utilitarian["SC1"]["PPO"] = 0.03
df_utilitarian["SC1"]["PPO NPS"] = 0.01
df_utilitarian["SC1"]["R2D2"] = 0.01
df_utilitarian["SC1"]["R2D2 NPS"] = 0.01

# Fill in values for third column of dataframe
df_utilitarian["SC2"]["A3C"] = 0.02
df_utilitarian["SC2"]["A3C NPS"] = 0.02
df_utilitarian["SC2"]["PPO"] = 0.02
df_utilitarian["SC2"]["PPO NPS"] = 0.03
df_utilitarian["SC2"]["R2D2"] = 0.02
df_utilitarian["SC2"]["R2D2 NPS"] = 0.02

# Fill in values for fourth column of dataframe
df_utilitarian["SC3"]["A3C"] = 0.03
df_utilitarian["SC3"]["A3C NPS"] = 0.03
df_utilitarian["SC3"]["PPO"] = 0.05
df_utilitarian["SC3"]["PPO NPS"] = 0.04
df_utilitarian["SC3"]["R2D2"] = 0.04
df_utilitarian["SC3"]["R2D2 NPS"] = 0.02

# Fill in values for fifth column of dataframe
df_utilitarian["SC4"]["A3C"] = 0.07
df_utilitarian["SC4"]["A3C NPS"] = 0.07
df_utilitarian["SC4"]["PPO"] = 0.06
df_utilitarian["SC4"]["PPO NPS"] = 0.08
df_utilitarian["SC4"]["R2D2"] = 0.07
df_utilitarian["SC4"]["R2D2 NPS"] = 0.05

# Fill in values for sixth column of dataframe
df_utilitarian["SC5"]["A3C"] = 0.08
df_utilitarian["SC5"]["A3C NPS"] = 0.06
df_utilitarian["SC5"]["PPO"] = 0.09
df_utilitarian["SC5"]["PPO NPS"] = 0.09
df_utilitarian["SC5"]["R2D2"] = 0.09
df_utilitarian["SC5"]["R2D2 NPS"] = 0.09

# %%
# min-max normalization of dataframe
df_utilitarian = (df_utilitarian - df_utilitarian.min()) / (df_utilitarian.max() - df_utilitarian.min())
df_utilitarian.fillna(0.0, inplace=True)
df_utilitarian
# Out:
#                SC0  SC1  SC2       SC3       SC4       SC5
# A3C       0.000000  0.5  0.0  0.333333  0.666667  0.666667
# A3C NPS   0.333333  1.0  0.0  0.333333  0.666667  0.000000
# PPO       1.000000  1.0  0.0  1.000000  0.333333  1.000000
# PPO NPS   0.000000  0.0  1.0  0.666667  1.000000  1.000000
# R2D2      0.333333  0.0  0.0  0.666667  0.666667  1.000000
# R2D2 NPS  0.333333  0.0  0.0  0.000000  0.000000  1.000000

# %%
# Plotting heatmap of dataframe
plt.figure(figsize=(10, 10))
sns.heatmap(df_utilitarian, annot=True, cmap="coolwarm")
plt.title("Prisoner's Dilemma - Utilitarian")
plt.show()

# %%
# Plottng all the heatmaps together in a 2x2 grid
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
sns.heatmap(df_focal_per_capita_return, annot=True, cmap="coolwarm", ax=axs[0, 0])
axs[0, 0].set_title("Focal Per Capita Return")
sns.heatmap(df_background_per_capita_return, annot=True, cmap="coolwarm", ax=axs[0, 1])
axs[0, 1].set_title("Background Per Capita Return")
sns.heatmap(df_per_capita_return, annot=True, cmap="coolwarm", ax=axs[1, 0])
axs[1, 0].set_title("Per Capita Return")
sns.heatmap(df_utilitarian, annot=True, cmap="coolwarm", ax=axs[1, 1])
axs[1, 1].set_title("Utilitarian")
plt.show()
